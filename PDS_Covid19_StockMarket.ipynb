# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Read-the-daily-confirmed-cases-and-deaths-into-two-dataframes" data-toc-modified-id="Read-the-daily-confirmed-cases-and-deaths-into-two-dataframes-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read the daily confirmed cases and deaths into two dataframes</a></span></li><li><span><a href="#Save-to-csv-files" data-toc-modified-id="Save-to-csv-files-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Save to csv files</a></span></li><li><span><a href="#Designate-API-key,-as-well-as-the-format-in-which-we-would-like-to-retrieve-the-data" data-toc-modified-id="Designate-API-key,-as-well-as-the-format-in-which-we-would-like-to-retrieve-the-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Designate API key, as well as the format in which we would like to retrieve the data</a></span></li></ul></div>

# %% [markdown]
# # Read the daily confirmed cases and deaths into two dataframes

# %%
! pip install alpha-vantage

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries

# %%
df_confirm=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_confirm
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/12/22  11/13/22  \
# ...

# %%
df_death=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
df_death
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/12/22  11/13/22  \
# ...

# %% [markdown]
# # Save to csv files

# %%
df_confirm.to_csv('Covid19_confirm.csv')
df_death.to_csv('Covid19_death.csv')

# %% [markdown]
# # Designate API key, as well as the format in which we would like to retrieve the data

# %%
demo = 'Q7GM02WT85BSSFZR' #YOUR API KEY HERE
alpha = pd.read_csv(
    'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=' + demo + '&datatype=csv')
alpha.head()
# Out:
#                                                    {
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
